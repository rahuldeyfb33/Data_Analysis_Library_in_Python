# %% [markdown]
# # Test pandas_cub manually
#
# In this notebook, we will test pandas_cub manually.

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Dell\\Anaconda3\\envs\\pandas_cub\\python.exe'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas_cub as pdc
import pandas_cub_final as pdcf
import pandas as pd

# %%
name = np.array(['Penelope', 'Niko', 'Eleni'])
state = np.array(['Texas', 'California', 'Texas'])
height = np.array([3.6, 3.5, 5.2])
school = np.array([True, False, True])
weight = np.array([45, 40, 130])

data = {'name': name, 'state': state, 'height': height, 
        'school': school, 'weight': weight}


df_final = pdcf.DataFrame(data)
df_pandas = pd.DataFrame(data)

# %%
df

# %%
df_final
# Out:
# <table><thead><tr><th></th><th>name      </th><th>state     </th><th>height    </th><th>school    </th><th>weight    </th></tr></thead><tbody><tr><td><strong>0</strong></td><td>Penelope  </td><td>Texas     </td><td>     3.600</td><td>True</td><td>        45</td></tr><tr><td><strong>1</strong></td><td>Niko      </td><td>California</td><td>     3.500</td><td>False</td><td>        40</td></tr><tr><td><strong>2</strong></td><td>Eleni     </td><td>Texas     </td><td>     5.200</td><td>True</td><td>       130</td></tr></tbody></table>

# %%
df_pandas
# Out:
#        name       state  height  school  weight
# 0  Penelope       Texas     3.6    True      45
# 1      Niko  California     3.5   False      40
# 2     Eleni       Texas     5.2    True     130

# %%
df = pdc.DataFrame(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-83da81120fb2> in <module>
# ----> 1 df = pdc.DataFrame(10)
#
# E:\rahul backup\BIG DATA NOTES\PYTHON project\PANDAS project\Git Project files\pandas_cub-master\pandas_cub\__init__.py in __init__(self, data)
#      18         """
#      19         # check for correct input types
# ---> 20         self._check_input_types(data)
#      21
#      22         # check for equal array lengths
#
# E:\rahul backup\BIG DATA NOTES\PYTHON project\PANDAS project\Git Project files\pandas_cub-master\pandas_cub\__init__.py in _check_input_types(self, data)
#      35     def _check_input_types(self, data):
#      36         if not isinstance(data, dict):
# ---> 37             raise TypeError(f'$data must be dictionary')
#      38
#      39     def _check_array_lengths(self, data):
#
# TypeError: $data must be dictionary

# %%
d ={'a':'a'}

# %%
pdc.DataFrame(d)
# Out:
# init method

# %%
values = np.column_stack((a, b, c, d, e))
# Out:
# -----------------------------------------------------------------
# NameError                       Traceback (most recent call last)
# <ipython-input-21-c73071ebe36a> in <module>
# ----> 1 values = np.column_stack((a, b, c, d, e))
#
# NameError: name 'a' is not defined

# %%
df_pandas.dtypes
# Out:
# name       object
# state      object
# height    float64
# school       bool
# weight      int32
# dtype: object
